# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv

# Load the CSV file
filePath = 'C:/Users/brean/Downloads/'
filename = 'MTT-esters-values-Sheet1.csv'
df = read_csv(filePath+filename)

# Calculate mean for 'Media Only' and 'Cells Only'
media_mean = df['Media Only'].mean()
cells_mean = df['Cells Only'].mean()

# Normalize data
normalized_df = (df - media_mean) / (cells_mean - media_mean) * 100

# Calculate means and standard deviations for normalized data
means_viability = normalized_df.mean()
stds_viability = normalized_df.std()

# Create a bar graph
plt.figure(figsize=(14, 6))
plt.bar(means_viability.index, means_viability.values, yerr=stds_viability.values, capsize=5, color='lightblue', edgecolor='black')
plt.axhline(0, color='red', linestyle='--')  # Line at y=0 for reference
plt.title('Normalized Percentage Cell Viability with Standard Deviations')
plt.xlabel('Treatments')
plt.ylabel('Percentage Cell Viability')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 8
#       6 filePath = 'C:/Users/brean/Downloads/'
#       7 filename = 'MTT-esters-values-Sheet1.csv'
# ----> 8 df = read_csv(filePath+filename)
#      10 # Calculate mean for 'Media Only' and 'Cells Only'
#      11 media_mean = df['Media Only'].mean()
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv

# Load the CSV file
filePath = 'C:/Users/brean/Downloads/'
filename = 'MTT.csv'
df = read_csv(filePath+filename)

# Calculate means for each column
means = df.mean()

# Normalize using Media Only and Cells Only means
media_only_mean = means['Media Only']
cells_only_mean = means['Cells Only']

# Normalize means of compounds
normalized_means = (means - media_only_mean) / (cells_only_mean - media_only_mean) * 100

# Calculate standard deviations for all columns
stds = df.std() * 100


# Create a bar graph
plt.figure(figsize=(14, 6))
plt.bar(normalized_means.index, normalized_means.values, yerr=stds.values, capsize=5, color='lightblue', edgecolor='black')
plt.axhline(0, color='red', linestyle='--')  # Line at y=0 for reference
plt.title('Normalized Percentage Cell Viability with Standard Deviations')
plt.xlabel('Treatments')
plt.ylabel('Percentage Cell Viability')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv

# Load the CSV file
filePath = 'C:/Users/brean/Downloads/'
filename = 'MTT.csv'
df = read_csv(filePath+filename)

# Calculate means for each column
means = df.mean()

# Normalize using Media Only and Cells Only means
media_only_mean = means['Media Only']
cells_only_mean = means['Cells Only']

# Normalize means of compounds
normalized_means = (means - media_only_mean) / (cells_only_mean - media_only_mean) * 100

# Calculate standard deviations for all columns
stds = df.std() * 100


# Create a bar graph
plt.figure(figsize=(14, 6))
plt.bar(normalized_means.index, normalized_means.values, yerr=stds.values, capsize=5, color='lightblue', edgecolor='black')
plt.axhline(0, color='red', linestyle='--')  # Line at y=0 for reference
plt.title('Normalized Percentage Cell Viability with Standard Deviations')
plt.xlabel('Treatments')
plt.ylabel('Percentage Cell Viability')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
df = pd.read_csv('MTT.csv')

# Calculate means for each column
means = df.mean()

# Normalize using Media Only and Cells Only means
media_only_mean = means['Media Only']
cells_only_mean = means['Cells Only']

normalized_means = (means - media_only_mean) / (cells_only_mean - media_only_mean) * 100

# Standard deviations (placeholder since we calculated means)
stds_placeholder = pd.Series([0] * len(normalized_means), index=normalized_means.index)

# Create a bar graph
plt.figure(figsize=(14, 6))
plt.bar(normalized_means.index, normalized_means.values, yerr=stds_placeholder.values, capsize=5, color='lightblue', edgecolor='black')
plt.axhline(0, color='red', linestyle='--')  # Line at y=0 for reference
plt.title('Normalized Percentage Cell Viability with Standard Deviations')
plt.xlabel('Treatments')
plt.ylabel('Percentage Cell Viability')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 5
#       2 import matplotlib.pyplot as plt
#       4 # Load the CSV file
# ----> 5 df = pd.read_csv('MTT.csv')
#       7 # Calculate means for each column
#       8 means = df.mean()
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv

# Load the CSV file
filePath = 'C:/Users/brean/Downloads/'
filename = 'MTT.csv'
df = read_csv(filePath+filename)

# Calculate means for each column
means = df.mean()

# Normalize using Media Only and Cells Only means
media_only_mean = means['Media Only']
cells_only_mean = means['Cells Only']

normalized_means = (means - media_only_mean) / (cells_only_mean - media_only_mean) * 100

# Standard deviations (placeholder since we calculated means)
stds_placeholder = pd.Series([0] * len(normalized_means), index=normalized_means.index)

# Create a bar graph
plt.figure(figsize=(14, 6))
plt.bar(normalized_means.index, normalized_means.values, yerr=stds_placeholder.values, capsize=5, color='lightblue', edgecolor='black')
plt.axhline(0, color='red', linestyle='--')  # Line at y=0 for reference
plt.title('Normalized Percentage Cell Viability with Standard Deviations')
plt.xlabel('Treatments')
plt.ylabel('Percentage Cell Viability')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv

# Load the CSV file
filePath = 'C:/Users/brean/Downloads/'
filename = 'MTT.csv'
df = read_csv(filePath+filename)

# Calculate means for each column
means = df.mean()

# Normalize using Media Only and Cells Only means
media_only_mean = means['Media Only']
cells_only_mean = means['Cells Only']

# Normalize means of compounds
normalized_means = (means - media_only_mean) / (cells_only_mean - media_only_mean) * 100

# Calculate standard deviations for all columns
stds = df.std() * 100


# Create a bar graph
plt.figure(figsize=(14, 6))
plt.bar(normalized_means.index, normalized_means.values, yerr=stds.values, capsize=5, color='lightblue', edgecolor='black')
plt.axhline(0, color='red', linestyle='--')  # Line at y=0 for reference
plt.title('Normalized Percentage Cell Viability with Standard Deviations')
plt.xlabel('Treatments')
plt.ylabel('Percentage Cell Viability')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv

# Load the CSV file
filePath = 'C:/Users/brean/Downloads/'
filename = 'MTT2.csv'
df = read_csv(filePath+filename)

# Calculate means for each column
means = df.mean()

# Normalize using Media Only and Cells Only means
media_only_mean = means['Media Only']
cells_only_mean = means['Cells Only']

# Normalize means of compounds
normalized_means = (means - media_only_mean) / (cells_only_mean - media_only_mean) * 100

# Calculate standard deviations for all columns
stds = df.std() * 100


# Create a bar graph
plt.figure(figsize=(14, 6))
plt.bar(normalized_means.index, normalized_means.values, yerr=stds.values, capsize=5, color='lightblue', edgecolor='black')
plt.axhline(0, color='red', linestyle='--')  # Line at y=0 for reference
plt.title('Normalized Percentage Cell Viability with Standard Deviations')
plt.xlabel('Treatments')
plt.ylabel('Percentage Cell Viability')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv

# Load the CSV file
filePath = 'C:/Users/brean/Downloads/'
filename = 'MTT-esters-1.csv'
df = read_csv(filePath+filename)

# Calculate means for each column
means = df.mean()

# Normalize using Media Only and Cells Only means
media_only_mean = means['Media Only']
cells_only_mean = means['Cells Only']

# Normalize means of compounds
normalized_means = (means - media_only_mean) / (cells_only_mean - media_only_mean) * 100

# Calculate standard deviations for all columns
stds = df.std() * 100


# Create a bar graph
plt.figure(figsize=(14, 6))
plt.bar(normalized_means.index, normalized_means.values, yerr=stds.values, capsize=5, color='lightblue', edgecolor='black')
plt.axhline(0, color='red', linestyle='--')  # Line at y=0 for reference
plt.title('Normalized Percentage Cell Viability with Standard Deviations')
plt.xlabel('Treatments')
plt.ylabel('Percentage Cell Viability')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 8
#       6 filePath = 'C:/Users/brean/Downloads/'
#       7 filename = 'MTT-esters-1.csv'
# ----> 8 df = read_csv(filePath+filename)
#      10 # Calculate means for each column
#      11 means = df.mean()
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv

# Load the CSV file
filePath = 'C:/Users/brean/Downloads/'
filename = 'MTT_esters_1.csv'
df = read_csv(filePath+filename)

# Calculate means for each column
means = df.mean()

# Normalize using Media Only and Cells Only means
media_only_mean = means['Media Only']
cells_only_mean = means['Cells Only']

# Normalize means of compounds
normalized_means = (means - media_only_mean) / (cells_only_mean - media_only_mean) * 100

# Calculate standard deviations for all columns
stds = df.std() * 100


# Create a bar graph
plt.figure(figsize=(14, 6))
plt.bar(normalized_means.index, normalized_means.values, yerr=stds.values, capsize=5, color='lightblue', edgecolor='black')
plt.axhline(0, color='red', linestyle='--')  # Line at y=0 for reference
plt.title('Normalized Percentage Cell Viability with Standard Deviations')
plt.xlabel('Treatments')
plt.ylabel('Percentage Cell Viability')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv

# Load the CSV file
filePath = 'C:/Users/brean/Downloads/'
filename = 'MTT_esters_1.csv'
df = read_csv(filePath+filename)

# Calculate means for each column
means = df.mean()

# Normalize using Media Only and Cells Only means
media_only_mean = means['Media Only']
cells_only_mean = means['Cells Only']

# Normalize means of compounds
normalized_means = (means - media_only_mean) / (cells_only_mean - media_only_mean) * 100

# Calculate standard deviations for all columns
stds = df.std() * 100

# Load CSV file containing additional data
filePath = 'C:/Users/brean/Downloads/'
filename = 'normalized_means_stdev.csv'
normalized_data = read_csv(filePath+filename)

# Extract pre-normalized means and standard deviations
pre_normalized_means = normalized_data.iloc[0].values
pre_normalized_stds = normalized_data.iloc[1].values * 100

# Combine calculated normalized means with pre-normalized means
combined_means = pd.concat([normalized_means, pd.Series(pre_normalized_means, index=normalized_data.columns)])

# Combine calculated standard deviations with pre-normalized standard deviations
combined_stds = pd.concat([stds, pd.Series(pre_normalized_stds, index=normalized_data.columns),])


# Create a bar graph
plt.figure(figsize=(14, 6))
plt.bar(combined_means.index, combined_means.values, yerr=combined_stds.values, capsize=5, color='lightblue', edgecolor='black')
plt.axhline(0, color='black', linestyle='--')  # Line at y=0 for reference
plt.title('Combined Normalized Percentage Cell Viability with Standard Deviations')
plt.xlabel('Treatments')
plt.ylabel('Percentage Cell Viability')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv
import scipy.stats as stats

# Load the CSV file
filePath = 'C:/Users/brean/Downloads/'
filename = 'MTT_esters_1.csv'
df = read_csv(filePath+filename)

# Calculate means for each column
means = df.mean()

# Normalize using Media Only and Cells Only means
media_only_mean = means['Media Only']
cells_only_mean = means['Cells Only']

# Normalize means of compounds
normalized_means = (means - media_only_mean) / (cells_only_mean - media_only_mean) * 100

# Calculate standard deviations for all columns
stds = df.std() * 100

# Load CSV file containing additional data
filePath = 'C:/Users/brean/Downloads/'
filename = 'normalized_means_stdev.csv'
normalized_data = read_csv(filePath+filename)

# Extract pre-normalized means and standard deviations
pre_normalized_means = normalized_data.iloc[0].values
pre_normalized_stds = normalized_data.iloc[1].values * 100

# Combine calculated normalized means with pre-normalized means
combined_means = pd.concat([normalized_means, pd.Series(pre_normalized_means, index=normalized_data.columns)])

# Combine calculated standard deviations with pre-normalized standard deviations
combined_stds = pd.concat([stds, pd.Series(pre_normalized_stds, index=normalized_data.columns),])


# Create a bar graph
plt.figure(figsize=(14, 6))
plt.bar(combined_means.index, combined_means.values, yerr=combined_stds.values, capsize=5, color='lightblue', edgecolor='black')
plt.axhline(0, color='black', linestyle='--')  # Line at y=0 for reference
plt.title('Combined Normalized Percentage Cell Viability with Standard Deviations')
plt.xlabel('Treatments')
plt.ylabel('Percentage Cell Viability')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# ANOVA statistical significance test
# Select treatment columns for ANOVA (assuming they start from the 3rd column onward)
anova_data = combined_means.iloc[:, 3:].dropna(how='all')  # Drop rows where all elements are NaN

# Check if there's any valid numerical data for proper ANOVA execution
if not anova_data.empty:
    # Perform one-way ANOVA
    f_statistic, p_value = stats.f_oneway(*[anova_data[col].dropna() for col in anova_data.columns])
else:
    f_statistic, p_value = None, None

# Output results
f_statistic, p_value
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 4
#       2 import matplotlib.pyplot as plt
#       3 from pandas import read_csv
# ----> 4 import scipy.stats as stats
#       6 # Load the CSV file
#       7 filePath = 'C:/Users/brean/Downloads/'
#
# ModuleNotFoundError: No module named 'scipy'

# %%
# !pip install scipy

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv
import scipy.stats as stats

# Load the CSV file
filePath = 'C:/Users/brean/Downloads/'
filename = 'MTT_esters_1.csv'
df = read_csv(filePath+filename)

# Calculate means for each column
means = df.mean()

# Normalize using Media Only and Cells Only means
media_only_mean = means['Media Only']
cells_only_mean = means['Cells Only']

# Normalize means of compounds
normalized_means = (means - media_only_mean) / (cells_only_mean - media_only_mean) * 100

# Calculate standard deviations for all columns
stds = df.std() * 100

# Load CSV file containing additional data
filePath = 'C:/Users/brean/Downloads/'
filename = 'normalized_means_stdev.csv'
normalized_data = read_csv(filePath+filename)

# Extract pre-normalized means and standard deviations
pre_normalized_means = normalized_data.iloc[0].values
pre_normalized_stds = normalized_data.iloc[1].values * 100

# Combine calculated normalized means with pre-normalized means
combined_means = pd.concat([normalized_means, pd.Series(pre_normalized_means, index=normalized_data.columns)])

# Combine calculated standard deviations with pre-normalized standard deviations
combined_stds = pd.concat([stds, pd.Series(pre_normalized_stds, index=normalized_data.columns),])


# Create a bar graph
plt.figure(figsize=(14, 6))
plt.bar(combined_means.index, combined_means.values, yerr=combined_stds.values, capsize=5, color='lightblue', edgecolor='black')
plt.axhline(0, color='black', linestyle='--')  # Line at y=0 for reference
plt.title('24 Hour MTT Assay')
plt.xlabel('Treatments')
plt.ylabel('Percentage Cell Viability')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# ANOVA statistical significance test

# Group the data
podo = combined_means[['Podo 50 µM', 'Podo 20 µM', 'Podo 10 µM', 'Podo 5 µM']]
piv = combined_means[['Piv 50 µM', 'Piv 20 µM', 'Piv 10 µM', 'Piv 5 µM']]
iso = combined_means[['Iso 50 µM', 'Iso 20 µM', 'Iso 10 µM', 'Iso 5 µM']]
hex = combined_means[['Hex 50 µM', 'Hex 20 µM', 'Hex 10 µM', 'Hex 5 µM']]
prop = combined_means[['Prop 50 µM', 'Prop 20 µM', 'Prop 10 µM', 'Prop 5 µM']]
acetate = combined_means[['Acetate 50 µM', 'Acetate 20 µM', 'Acetate 10 µM', 'Acetate 5 µM']]
phenyl_acetate = combined_means[['Phenyl Acetate 50 µM', 'Phenyl Acetate 20 µM', 'Phenyl Acetate 10 µM', 'Phenyl Acetate 5 µM']]

# Perform one-way ANOVA
f_statistic, p_value = stats.f_oneway(podo, piv, iso, hex, prop, acetate, phenyl_acetate)

print(f"F-statistic: {f_statistic}")
print(f"p-value: {p_value}")
# Out:
# F-statistic: 5.202601726880761
# p-value: 0.0020258789105782227

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv
import scipy.stats as stats

# Load the CSV file
filePath = 'C:/Users/brean/Downloads/'
filename = 'MTT_esters_1.csv'
df = read_csv(filePath+filename)

# Calculate means for each column
means = df.mean()

# Normalize using Media Only and Cells Only means
media_only_mean = means['Media Only']
cells_only_mean = means['Cells Only']

# Normalize means of compounds
normalized_means = (means - media_only_mean) / (cells_only_mean - media_only_mean) * 100

# Calculate standard deviations for all columns
stds = df.std() * 100

# Split dataframe

normalized_df = pd.DataFrame(normalized_means).T

media_cells_dmso = normalized_df.iloc[0:3].values
rest = normalized_df.iloc[3:].values

stds_df = pd.DataFrame(stds).T

media_cells_dmso_stds = stds_df.iloc[0:3].values
rest_stds = stds_df.iloc[3:].values

# Load CSV file containing additional data
filePath = 'C:/Users/brean/Downloads/'
filename = 'normalized_means_stdev.csv'
normalized_data = read_csv(filePath+filename)

# Extract pre-normalized means and standard deviations
pre_normalized_means_podo = normalized_data.iloc[0, 0:4].values
pre_normalized_stds_podo = normalized_data.iloc[1, 0:4].values * 100

pre_normalized_means_rest = normalized_data.iloc[0, 4:].values
pre_normalized_stds_rest = normalized_data.iloc[1, 4:].values * 100

# Make new dataframes

podo_means_df = pd.DataFrame({ 'Podo Means': pre_normalized_means_podo, 'Podo Stdev': pre_normalized_stds_podo, index = normalized_data.columns[:4]})
other_compounds_df = pd.DataFrame({'Other means': pre_normalized_means_rest, 'Other stdev': pre_normalized_stds_rest, index = normalized_data.columns[4:]})


# Combine calculated normalized means with pre-normalized means
combined_means = pd.concat([media_cells_dmso, 'Podo Means', rest, 'Other means'])

# Combine calculated standard deviations with pre-normalized standard deviations
combined_stds = pd.concat([media_cells_dmso_stds, 'Podo Stdev', rest_stds, 'Other stdev'])


# Create a bar graph
plt.figure(figsize=(14, 6))
plt.bar(combined_means.index, combined_means.values, yerr=combined_stds.values, capsize=5, color='lightblue', edgecolor='black')
plt.axhline(0, color='black', linestyle='--')  # Line at y=0 for reference
plt.title('24 Hour MTT Assay')
plt.xlabel('Treatments')
plt.ylabel('Percentage Cell Viability')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# ANOVA statistical significance test

# Group the data
podo = combined_means[['Podo 50 µM', 'Podo 20 µM', 'Podo 10 µM', 'Podo 5 µM']]
piv = combined_means[['Piv 50 µM', 'Piv 20 µM', 'Piv 10 µM', 'Piv 5 µM']]
iso = combined_means[['Iso 50 µM', 'Iso 20 µM', 'Iso 10 µM', 'Iso 5 µM']]
hex = combined_means[['Hex 50 µM', 'Hex 20 µM', 'Hex 10 µM', 'Hex 5 µM']]
prop = combined_means[['Prop 50 µM', 'Prop 20 µM', 'Prop 10 µM', 'Prop 5 µM']]
acetate = combined_means[['Acetate 50 µM', 'Acetate 20 µM', 'Acetate 10 µM', 'Acetate 5 µM']]
phenyl_acetate = combined_means[['Phenyl Acetate 50 µM', 'Phenyl Acetate 20 µM', 'Phenyl Acetate 10 µM', 'Phenyl Acetate 5 µM']]

# Perform one-way ANOVA
f_statistic, p_value = stats.f_oneway(podo, piv, iso, hex, prop, acetate, phenyl_acetate)

print(f"F-statistic: {f_statistic}")
print(f"p-value: {p_value}")
# Out:
#   Cell In[11], line 50
#     podo_means_df = pd.DataFrame({ 'Podo Means': pre_normalized_means_podo, 'Podo Stdev': pre_normalized_stds_podo, index = normalized_data.columns[:4]})
#                                                                                                                         ^
# SyntaxError: ':' expected after dictionary key

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv
import scipy.stats as stats

# Load the CSV file
filePath = 'C:/Users/brean/Downloads/'
filename = 'MTT_esters_1.csv'
df = read_csv(filePath+filename)

# Calculate means for each column
means = df.mean()

# Normalize using Media Only and Cells Only means
media_only_mean = means['Media Only']
cells_only_mean = means['Cells Only']

# Normalize means of compounds
normalized_means = (means - media_only_mean) / (cells_only_mean - media_only_mean) * 100

# Calculate standard deviations for all columns
stds = df.std() * 100

# Split dataframe for normalized means
normalized_df = pd.DataFrame(normalized_means).T

media_cells_dmso = normalized_df.iloc[0, 0:3]
rest = normalized_df.iloc[0, 3:]

# Split dataframe for stdev 
stds_df = pd.DataFrame(stds).T

media_cells_dmso_stds = stds_df.iloc[0, 0:3]
rest_stds = stds_df.iloc[0, 3:]

# Load CSV file containing additional data
filePath = 'C:/Users/brean/Downloads/'
filename = 'normalized_means_stdev.csv'
normalized_data = read_csv(filePath+filename)

# Extract pre-normalized means and standard deviations
pre_normalized_means_podo = normalized_data.iloc[0, 0:4]
pre_normalized_stds_podo = normalized_data.iloc[1, 0:4] * 100

pre_normalized_means_rest = normalized_data.iloc[0, 4:]
pre_normalized_stds_rest = normalized_data.iloc[1, 4:] * 100

# Make new dataframes
podo_means_df = pd.DataFrame({'Podo Means': pre_normalized_means_podo, 'Podo Stdev': pre_normalized_stds_podo})
other_compounds_df = pd.DataFrame({'Other means': pre_normalized_means_rest, 'Other stdev': pre_normalized_stds_rest})

# Combine calculated normalized means with pre-normalized means
combined_means = pd.concat([media_cells_dmso, podo_means_df['Podo Means'], rest, other_compounds_df['Other means']])

# Combine calculated standard deviations with pre-normalized standard deviations
combined_stds = pd.concat([media_cells_dmso_stds, podo_means_df['Podo Stdev'], rest_stds, other_compounds_df['Other stdev']])

# Create a bar graph
plt.figure(figsize=(14, 6))
plt.bar(combined_means.index, combined_means.values, yerr=combined_stds.values, capsize=5, color='lightblue', edgecolor='black')
plt.axhline(0, color='black', linestyle='--')  # Line at y=0 for reference
plt.title('24 Hour MTT Assay')
plt.xlabel('Treatments')
plt.ylabel('Percentage Cell Viability')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# ANOVA statistical significance test

# Group the data
podo = combined_means[['Podo 50 µM', 'Podo 20 µM', 'Podo 10 µM', 'Podo 5 µM']]
piv = combined_means[['Piv 50 µM', 'Piv 20 µM', 'Piv 10 µM', 'Piv 5 µM']]
iso = combined_means[['Iso 50 µM', 'Iso 20 µM', 'Iso 10 µM', 'Iso 5 µM']]
hex = combined_means[['Hex 50 µM', 'Hex 20 µM', 'Hex 10 µM', 'Hex 5 µM']]
prop = combined_means[['Prop 50 µM', 'Prop 20 µM', 'Prop 10 µM', 'Prop 5 µM']]
acetate = combined_means[['Acetate 50 µM', 'Acetate 20 µM', 'Acetate 10 µM', 'Acetate 5 µM']]
phenyl_acetate = combined_means[['Phenyl Acetate 50 µM', 'Phenyl Acetate 20 µM', 'Phenyl Acetate 10 µM', 'Phenyl Acetate 5 µM']]

# Perform one-way ANOVA
f_statistic, p_value = stats.f_oneway(podo, piv, iso, hex, prop, acetate, phenyl_acetate)

print(f"F-statistic: {f_statistic}")
print(f"p-value: {p_value}")
# Out:
# F-statistic: 5.202601726880761
# p-value: 0.0020258789105782227

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv
import scipy.stats as stats

# Load the CSV file
filePath = 'C:/Users/brean/Downloads/'
filename = 'MTT_esters_1.csv'
df = read_csv(filePath+filename)

# Calculate means for each column
means = df.mean()

# Normalize using Media Only and Cells Only means
media_only_mean = means['Media Only']
cells_only_mean = means['Cells Only']

# Normalize means of compounds
normalized_means = (means - media_only_mean) / (cells_only_mean - media_only_mean) * 100

# Calculate standard deviations for all columns
stds = df.std() * 100

# Split dataframe for normalized means
normalized_df = pd.DataFrame(normalized_means).T

media_cells_dmso = normalized_df.iloc[:, 0:3]
rest = normalized_df.iloc[:, 3:]

# Split dataframe for stdev 
stds_df = pd.DataFrame(stds).T

media_cells_dmso_stds = stds_df.iloc[:, 0:3]
rest_stds = stds_df.iloc[:, 3:]

# Load CSV file containing additional data
filePath = 'C:/Users/brean/Downloads/'
filename = 'normalized_means_stdev.csv'
normalized_data = read_csv(filePath+filename)

# Extract pre-normalized means and standard deviations
pre_normalized_means_podo = normalized_data.iloc[0, 0:4]
pre_normalized_stds_podo = normalized_data.iloc[1, 0:4] * 100

pre_normalized_means_rest = normalized_data.iloc[0, 4:]
pre_normalized_stds_rest = normalized_data.iloc[1, 4:] * 100

# Make new dataframes
podo_means_df = pd.DataFrame({'Podo Means': pre_normalized_means_podo, 'Podo Stdev': pre_normalized_stds_podo})
other_compounds_df = pd.DataFrame({'Other means': pre_normalized_means_rest, 'Other stdev': pre_normalized_stds_rest})

# Combine calculated normalized means with pre-normalized means
combined_means = pd.concat([media_cells_dmso.iloc[0], podo_means_df['Podo Means'], rest.iloc[0], other_compounds_df['Other means']])

# Combine calculated standard deviations with pre-normalized standard deviations
combined_stds = pd.concat([media_cells_dmso_stds.iloc[0], podo_means_df['Podo Stdev'], rest_stds.iloc[0], other_compounds_df['Other stdev']])

# Create a bar graph
plt.figure(figsize=(14, 6))
plt.bar(combined_means.index, combined_means.values, yerr=combined_stds.values, capsize=5, color='lightblue', edgecolor='black')
plt.axhline(0, color='black', linestyle='--')  # Line at y=0 for reference
plt.title('24 Hour MTT Assay')
plt.xlabel('Treatments')
plt.ylabel('Percentage Cell Viability')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# ANOVA statistical significance test

# Group the data
podo = combined_means[['Podo 50 µM', 'Podo 20 µM', 'Podo 10 µM', 'Podo 5 µM']]
piv = combined_means[['Piv 50 µM', 'Piv 20 µM', 'Piv 10 µM', 'Piv 5 µM']]
iso = combined_means[['Iso 50 µM', 'Iso 20 µM', 'Iso 10 µM', 'Iso 5 µM']]
hex = combined_means[['Hex 50 µM', 'Hex 20 µM', 'Hex 10 µM', 'Hex 5 µM']]
prop = combined_means[['Prop 50 µM', 'Prop 20 µM', 'Prop 10 µM', 'Prop 5 µM']]
acetate = combined_means[['Acetate 50 µM', 'Acetate 20 µM', 'Acetate 10 µM', 'Acetate 5 µM']]
phenyl_acetate = combined_means[['Phenyl Acetate 50 µM', 'Phenyl Acetate 20 µM', 'Phenyl Acetate 10 µM', 'Phenyl Acetate 5 µM']]

# Perform one-way ANOVA
f_statistic, p_value = stats.f_oneway(podo, piv, iso, hex, prop, acetate, phenyl_acetate)

print(f'F-statistic: {f_statistic}')
print(f'p-value: {p_value}')
# Out:
# F-statistic: 5.202601726880761
# p-value: 0.0020258789105782227
